# %% [markdown]
# # Segment audios

# %%
import os

# Data Management
import pandas as pd

import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Audio
from pydub import AudioSegment

# %%
# mount unit e in linux
# os.system("sudo mount -t drvfs E: /mnt/e")

# %%
# !ls ../../../../../../mnt/e/Posidonia\ Soundscapes/Predictions
# Out:
# 20250515_190050.csv  20250516_184220.csv  20250517_182350.csv
# 20250515_190355.csv  20250516_184525.csv  20250517_182655.csv
# 20250515_190700.csv  20250516_184830.csv  20250517_183000.csv
# 20250515_191005.csv  20250516_185135.csv  20250517_183305.csv
# 20250515_191310.csv  20250516_185440.csv  20250517_183610.csv
# 20250515_191615.csv  20250516_185745.csv  20250517_183915.csv
# 20250515_191920.csv  20250516_190050.csv  20250517_184220.csv
# 20250515_192225.csv  20250516_190355.csv  20250517_184525.csv
# 20250515_192530.csv  20250516_190700.csv  20250517_184830.csv
# 20250515_192835.csv  20250516_191005.csv  20250517_185135.csv
# 20250515_193140.csv  20250516_191310.csv  20250517_185440.csv
# 20250515_193445.csv  20250516_191615.csv  20250517_185745.csv
# 20250515_193750.csv  20250516_191920.csv  20250517_190050.csv
# 20250515_194055.csv  20250516_192225.csv  20250517_190355.csv
# 20250515_194400.csv  20250516_192530.csv  20250517_190700.csv
# ...

# %%
PREDICTIONS = "Fondeo4_Model31"

# %%
import pandas as pd

# Load CSV predictions.csv
# df = pd.read_csv(f'../../../../../../mnt/e/DeepLearning/Predictions/whistle_predictions.csv')
df = pd.read_csv(f'../../../../../../mnt/e/Posidonia Soundscapes/Predictions/predictions.csv')
#Keep only rows where MainClassification is Whistle
df = df[df['MainClassification'] == 'Whistle']
# reset index
df = df.reset_index(drop=True)
df
# Out:
#                                                    Path             Filename  \
# 0     D:/Posidonia Soundscapes/Hydromoth/20250515_19...  20250515_190050.WAV
# 1     D:/Posidonia Soundscapes/Hydromoth/20250515_19...  20250515_190050.WAV
# 2     D:/Posidonia Soundscapes/Hydromoth/20250515_19...  20250515_190050.WAV
# 3     D:/Posidonia Soundscapes/Hydromoth/20250515_19...  20250515_190050.WAV
# 4     D:/Posidonia Soundscapes/Hydromoth/20250515_19...  20250515_190050.WAV
# ...                                                 ...                  ...
# 3594  D:/Posidonia Soundscapes/Hydromoth/20250518_17...  20250518_174955.WAV
# 3595  D:/Posidonia Soundscapes/Hydromoth/20250518_17...  20250518_174955.WAV
# 3596  D:/Posidonia Soundscapes/Hydromoth/20250518_17...  20250518_175300.WAV
# 3597  D:/Posidonia Soundscapes/Hydromoth/20250518_17...  20250518_175300.WAV
# 3598  D:/Posidonia Soundscapes/Hydromoth/20250518_17...  20250518_175605.WAV
#
# ...

# %%
species = df["MainClassification"].unique()
species
# Out:
# array(['Whistle'], dtype=object)

# %%
# HARD_DRIVE = "f"
# OS = "WSL"

# import subprocess
# from NO_SHARABLE import PASSWORD

# if OS == "WSL":
#     command = f'mount -t drvfs F: /mnt/{HARD_DRIVE}'

#     try:
#         # Ejecutar el comando como sudo
#         proc = subprocess.Popen(
#             ['sudo', '-S'] + command.split(),
#             stdin=subprocess.PIPE,
#             stdout=subprocess.PIPE,
#             stderr=subprocess.PIPE,
#             universal_newlines=True
#         )

#         # Enviar la contraseña seguido de un salto de línea
#         stdout, stderr = proc.communicate(PASSWORD + '\n')

#         print('STDOUT:', stdout)
#         print('STDERR:', stderr)

#         if proc.returncode == 0:
#             print("Hard drive mounted successfully")
#             HARD_DRIVE = HARD_DRIVE
#         else:
#             print("Failed to mount hard drive")

#     except Exception as e:
#         print(f"An error occurred: {e}")

# %%
import os

# %%
for specie in species:
    # Load the subset
    subset = df[df["MainClassification"] == specie]
    subset = subset.reset_index(drop=True)
    print(len(subset))
# Out:
# 3599

# %%
import os
from pydub import AudioSegment
# import pandas as pd

# %%
# Load CSV predictions.csv
# df = pd.read_csv(f'../../../../../mnt/e/Deep Learning Analysis/Predictions/{PREDICTIONS}/predictions_to_validate.csv')

species = df["MainClassification"].unique()

# take for each MainClassification the 100 samples with the highest confidence
# df = df.sort_values(by=["ConfidenceScore"], ascending=False).groupby("MainClassification").head(100)

# count of rows per MainClassification
df["MainClassification"].value_counts()
# Out:
# MainClassification
# Whistle    3599
# Name: count, dtype: int64

# %%
CLASSES_MAPPING = {
    'Background': 0,
    'Whistle': 1,
}

# Reverse mapping for easy lookup
IDX_TO_CLASSES = {v: k for k, v in CLASSES_MAPPING.items()}

# %%
# df["BackgroundConfidenceScore"] = df["ConfidenceVector"].apply(lambda x: eval(x)[0])

# %%
# df["ConfidenceSpecieBackground"] = df["ConfidenceScore"] - df["BackgroundConfidenceScore"]

# %%
def cut_audio(prediction, output_folder, audios_folder="../Audios/"):
    file = prediction["Path"]
    file = file.split("D:/")[1]
    file = file.replace("\\", "/")

    start_time = max(0, int(prediction["StartSecond"] * 1000) - 2000)  # Convert to ms
    end_time = int(prediction["EndSecond"] * 1000) + 2000  # Convert to ms

    if end_time - start_time < 7000:
        print(f"Warning: {file} has a length less than 7 seconds, extending to 7 seconds.")
        end_time = start_time + 7000  # Ensure at least 7 seconds

    start_time = int(start_time)
    end_time = int(end_time)

    scientific_name = prediction["MainClassification"]
    confidence = prediction["ConfidenceScore"]
    confidence = round(confidence, 2)

    base_filename = os.path.basename(file)
    # Extract base folder name for subfolder naming
    folder_name = os.path.basename(os.path.dirname(file))

    # Find the next subfolder with less than 50 files
    subfolder_index = 1
    while True:
        output_folder_specie = os.path.join(
            output_folder, f"{folder_name}_{subfolder_index}", scientific_name
        )
        os.makedirs(output_folder_specie, exist_ok=True)
        existing_files = [
            f for f in os.listdir(output_folder_specie) if f.lower().endswith('.wav')
        ]
        if len(existing_files) < 50:
            break
        subfolder_index += 1

    output_file = os.path.join(
        output_folder_specie,
        f"{base_filename.replace('.WAV', '')}_{start_time // 1000}_{end_time // 1000}_{confidence}.WAV"
    )

    if not os.path.exists(output_file):
        audio_file = os.path.join(audios_folder, file)
        if not os.path.exists(audio_file):
            print(f"Warning: {audio_file} not found!")
            return

        try:
            audio = AudioSegment.from_wav(audio_file)
            if end_time > len(audio):
                end_time = len(audio)
                if end_time - start_time < 7000:
                    print(f"Warning: {output_file} has a length less than 7 seconds, extending to 7 seconds.")
                    start_time = max(0, end_time - 7000)  # Ensure at least 7 seconds
                    # update output_file with new start_time
                    output_file = os.path.join(
                        output_folder_specie,
                        f"{base_filename.replace('.WAV', '')}_{start_time // 1000}_{end_time // 1000}_{confidence}.WAV"
                    )
            if end_time - start_time < 0:
                print(f"Warning: {output_file} has a negative length!")
                return
            cut_audio_seg = audio[start_time:end_time]
            print(f"Exporting {output_file}...")
            cut_audio_seg.export(output_file, format="wav")
        except FileNotFoundError:
            print(f"Error: Input file {audio_file} not found!")
        except Exception as e:
            print(f"Error processing {audio_file}: {e}")
    else:
        print(f"File {output_file} already exists")


AudioFolder = f"/mnt/e/Posidonia Soundscapes/Segments"

for specie in species:
    subset = df[df["MainClassification"] == specie].reset_index(drop=True)
    output_folder = f"{AudioFolder}/"
    os.makedirs(output_folder, exist_ok=True)
    for index, row in subset.iterrows():
        cut_audio(row, output_folder, audios_folder=f"/mnt/e/")
# Out:
# ...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Hydromoth_1/Whistle/20250515_190050_0_7_0.81.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Hydromoth_1/Whistle/20250515_190050_1_8_0.57.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Hydromoth_1/Whistle/20250515_190050_10_17_0.82.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Hydromoth_1/Whistle/20250515_190050_13_20_0.96.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Hydromoth_1/Whistle/20250515_190050_16_23_0.67.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Hydromoth_1/Whistle/20250515_190050_28_35_0.76.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Hydromoth_1/Whistle/20250515_190050_34_41_0.72.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Hydromoth_1/Whistle/20250515_190050_37_44_0.85.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Hydromoth_1/Whistle/20250515_190050_40_47_0.75.WAV...
# ...

# %%
# Change all folders Hydrophone names to PosidoniaSoundscape_Deployment1_Hydrophone
for root, dirs, files in os.walk(AudioFolder):
    for dir_name in dirs:
        if "Hydromoth" in dir_name:
            new_dir_name = dir_name.replace("Hydromoth", "PosidoniaSoundscape_Deployment1_Hydromoth")
            os.rename(os.path.join(root, dir_name), os.path.join(root, new_dir_name))
            print(f"Renamed {dir_name} to {new_dir_name}")
# Out:
# Renamed PosidoniaSoundscape_Deployment1_Hydrophone_10 to PosidoniaSoundscape_Deployment1_Hydromoth_10
# Renamed PosidoniaSoundscape_Deployment1_Hydrophone_11 to PosidoniaSoundscape_Deployment1_Hydromoth_11
# Renamed PosidoniaSoundscape_Deployment1_Hydrophone_12 to PosidoniaSoundscape_Deployment1_Hydromoth_12
# Renamed PosidoniaSoundscape_Deployment1_Hydrophone_13 to PosidoniaSoundscape_Deployment1_Hydromoth_13
# Renamed PosidoniaSoundscape_Deployment1_Hydrophone_14 to PosidoniaSoundscape_Deployment1_Hydromoth_14
# Renamed PosidoniaSoundscape_Deployment1_Hydrophone_15 to PosidoniaSoundscape_Deployment1_Hydromoth_15
# Renamed PosidoniaSoundscape_Deployment1_Hydrophone_16 to PosidoniaSoundscape_Deployment1_Hydromoth_16
# Renamed PosidoniaSoundscape_Deployment1_Hydrophone_17 to PosidoniaSoundscape_Deployment1_Hydromoth_17
# Renamed PosidoniaSoundscape_Deployment1_Hydrophone_18 to PosidoniaSoundscape_Deployment1_Hydromoth_18
# ...

# %%
def cut_audio(prediction, output_folder, audios_folder="../Audios/"):
    file = prediction["Path"]
    file = file.split("D:/")[1]
    file = file.replace("\\", "/")
    # print(file)

    start_time = max(0, int(prediction["StartSecond"] * 1000) - 2000)  # Convert to ms
    end_time = int(prediction["EndSecond"] * 1000)

    start_time = int(start_time)
    end_time = int(end_time)

    scientific_name = prediction["MainClassification"]
    confidence = prediction["ConfidenceScore"]
    # round to 2 decimals
    confidence = round(confidence, 2)

    # Get the output folder
    output_folder_specie = os.path.join(output_folder, scientific_name)
    os.makedirs(output_folder_specie, exist_ok=True)

    # Get the output file path
    base_filename = os.path.basename(file)
    output_file = os.path.join(
        output_folder_specie, f"{base_filename.replace('.wav', '')}_{start_time // 1000}_{end_time // 1000}_{confidence}.WAV"
    )

    if not os.path.exists(output_file):
        # Get the audio file
        audio_file = os.path.join(audios_folder,file)
        # print(audios_folder, file)

        if not os.path.exists(audio_file):
            print(f"Warning: {audio_file} not found!")
            return

        try:
            # Load the audio file
            audio = AudioSegment.from_wav(audio_file)

            # if end_time is greater than the length of the audio, set it to the length of the audio
            if end_time > len(audio):
                end_time = len(audio)

            if end_time - start_time < 0:
                print(f"Warning: {output_file} has a negative length!")
                return

            # Cut the audio segment
            cut_audio = audio[start_time:end_time]

            print(f"Exporting {output_file}...")

            # Export the cut audio segment
            cut_audio.export(output_file, format="wav")
        except FileNotFoundError:
            print(f"Error: Input file {audio_file} not found!")
        except Exception as e:
            print(f"Error processing {audio_file}: {e}")
    else:
        print(f"File {output_file} already exists")


AudioFolder = f"/mnt/e/Posidonia Soundscapes/Segments"

for specie in species:
    # Load the subset
    subset = df[df["MainClassification"] == specie]
    # reset index
    subset = subset.reset_index(drop=True)
    # For each subset saved in a csv, save in a different folder
    output_folder = f"{AudioFolder}/"
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    # Cut the audio for each row in the subset
    for index, row in subset.iterrows():
        cut_audio(row, output_folder, audios_folder = f"/mnt/e/")
# Out:
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Whistle/20250515_190050.WAV_0_3_0.81.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Whistle/20250515_190050.WAV_1_6_0.57.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Whistle/20250515_190050.WAV_10_15_0.82.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Whistle/20250515_190050.WAV_13_18_0.96.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Whistle/20250515_190050.WAV_16_21_0.67.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Whistle/20250515_190050.WAV_28_33_0.76.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Whistle/20250515_190050.WAV_34_39_0.72.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Whistle/20250515_190050.WAV_37_42_0.85.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Whistle/20250515_190050.WAV_40_45_0.75.WAV...
# Exporting /mnt/e/Posidonia Soundscapes/Segments/Whistle/20250515_190050.WAV_43_48_0.83.WAV...
# ...

# %%
# Copy folder with .WAV files to a new folder with .mp3 format
import shutil
import os
import glob
from pydub import AudioSegment
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

# Define the source and destination directories
source_dir = f"/mnt/e/DeepLearning/Segments/Whistle/"
destination_dir = f"/mnt/e/DeepLearning/Segments_mp3/Whistle/"
# Create the destination directory if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)
# Get a list of all .WAV files in the source directory
wav_files = glob.glob(os.path.join(source_dir, "*.WAV"))
# Loop through each .WAV file
for wav_file in wav_files:
    # Get the base name of the file (without the directory)
    base_name = os.path.basename(wav_file)
    # Create the new file name with .mp3 extension
    new_file_name = os.path.splitext(base_name)[0] + ".mp3"
    # Define the destination path
    destination_path = os.path.join(destination_dir, new_file_name)
    # Convert .WAV to .mp3 using pydub
    audio = AudioSegment.from_wav(wav_file)
    audio.export(destination_path, format="mp3")
    # generate mel spectrogram with librosa
    try:
        y, sr = librosa.load(destination_path)
        mel = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
        # Save the mel spectrogram as an image
        plt.figure(figsize=(10, 4))
        librosa.display.specshow(librosa.power_to_db(mel, ref=np.max), y_axis='mel', x_axis='time')
        plt.axis('off')  # Remove axis
        plt.tight_layout()
        plt.savefig(destination_path.replace(".mp3", ".png"), bbox_inches='tight', pad_inches=0)
        plt.close()
    except Exception as e:
        # delete the file if it fails
        os.remove(destination_path)
        print(f"Failed to process {destination_path}: {e}")
# Out:
# [src/libmpg123/parse.c:do_readahead():1083] warning: Cannot read next header, a one-frame stream? Duh...
# /tmp/ipykernel_2555142/2025151210.py:31: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(destination_path)
# /home/gruncrow/anaconda3/envs/DataAnalysis/lib/python3.12/site-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Failed to process /mnt/e/DeepLearning/Segments_mp3/Whistle/channelA_2024-06-26_11-38-05_1279_1200_0.58.mp3:
# [src/libmpg123/parse.c:do_readahead():1083] warning: Cannot read next header, a one-frame stream? Duh...
# /tmp/ipykernel_2555142/2025151210.py:31: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(destination_path)
# ...
